# %%
import requests
from bs4 import BeautifulSoup

form_data = {
    'keyword': '香蕉',
    'division_lv1': '*',
    'year': 102,
    'month': 1,
    'end_year': 110,
    'end_month': 6,
    'search_Submit': '查詢',
    'is_search': 'y'
}

headers = {
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36',
}
url = 'https://www.coa.gov.tw/theme_list.php?theme=news&sub_theme=agri'
ss = requests.session()
res = ss.post(url=url, headers=headers, data=form_data)
soup = BeautifulSoup(res.text, 'html.parser')

ID = []
date = []
title = []
author = []
link = []
content = []


# 取文號
for a in soup.select('td[class="word"]'):
    ID.append(a.text)

# 取發布日期
for b in range(1, len(soup.select('td[align="center"]')), 3):
    newsDate = soup.select('td[align="center"]')[b]
    date.append(newsDate.text)

# 取發布機關
for c in range(2, len(soup.select('td[align="center"]')), 3):
    newsAuthor = soup.select('td[align="center"]')[c]
    author.append(newsAuthor.text)

# 取新聞標題、網址
for i in range(0, len(soup.select('a[class="main-c9-index"]'))):
    newsTitle = soup.select('a[class="main-c9-index"]')[i]['title']
    newsLink = 'https://www.coa.gov.tw/' + soup.select('a[class="main-c9-index"]')[i]['href']
    title.append(newsTitle)
    link.append(newsLink)

# 取新聞內容
for j in range(len(link)):
    page_res = ss.get(url=link[j], headers=headers)
    page_soap = BeautifulSoup(page_res.text, 'html.parser')
    for w in page_soap.select('div[class="word"]'):
        content.append (w.text)


# print(ID)
# print(date)
# print(title)
# print(author)
# print(link)
# print(content)

# %%
import pandas as pd
import csv


dict = {'文號': ID, '發布日期': date, '標題': title, '發布機關': author, '網址': link, '內容': content}
df = pd.DataFrame(dict)
df.to_csv('農委會新聞_香蕉.csv')
df
# Out:
#           文號       發布日期                              標題      發布機關  \
# 0       8747  110-06-03             慎防彩雲颱風 農委會籲請農漁民及早防範  農委會(輔導處)
# 1       8722  110-04-09  日商Farmind株式會社承諾購買3,000公噸臺灣優質鳳梨  農委會(國際處)
# 2       8713  110-03-13  少數業者輸日香蕉藥殘不符規定，農委會輔導業者落實安全用藥管理       農糧署
# 3       8709  110-03-04  台農發公司拓展農產品外銷新市場成果豐碩  農委會給予高度肯定  農委會(國際處)
# 4       8685  110-01-21         智慧農業計畫研發有成 鋼鐵農夫 肩頸不再頂扣扣  農委會(科技處)
# ..       ...        ...                             ...       ...
# 192  1030923  103-09-23                  103年鳳凰颱風農業災情報告  農委會(統計室)
# 193  1030730  103-07-30                103年麥德姆颱風農業災情報告   農委會(統計室)
# 194  1020926  102-09-26                      天兔颱風農業災情報告  農委會(統計室)
# 195           105-09-28                105年9月梅姬颱風農業災情報告  農委會(統計室)
# 196           105-09-29                105年9月梅姬颱風農業災情報告  農委會(統計室)
#
#                                                     網址  \
# 0    https://www.coa.gov.tw/theme_data.php?theme=ne...
# 1    https://www.coa.gov.tw/theme_data.php?theme=ne...
# 2    https://www.coa.gov.tw/theme_data.php?theme=ne...
# 3    https://www.coa.gov.tw/theme_data.php?theme=ne...
# 4    https://www.coa.gov.tw/theme_data.php?theme=ne...
# ..                                                 ...
# 192  https://www.coa.gov.tw/theme_data.php?theme=ne...
# 193  https://www.coa.gov.tw/theme_data.php?theme=ne...
# 194  https://www.coa.gov.tw/theme_data.php?theme=ne...
# 195  https://www.coa.gov.tw/theme_data.php?theme=ne...
# 196  https://www.coa.gov.tw/theme_data.php?theme=ne...
#
#                                                     內容
# 0    　　中央氣象局於本(3)日發布輕度颱風「彩雲」海上颱風警報，颱風中心目前在鵝鑾鼻南南西方海面...
# 1           農委會陳吉仲主任委員4月9日與日本Farmind株式會社崛內達生社長舉行視訊會...
# 2    　　針對本(13)日媒體報導我國某出口業者輸日香蕉被驗出殺菌劑百克敏劑量超標，違反日本農藥殘...
# 3           對於本(4)日部分政治人物批評台農發公司營運績效不彰，農委會表示，台農發公司現...
# 4          「工作時手臂一直抬高，手臂好痠喔！」，農友們的心聲，行政院農業委員會聽到了！為減...
# ..                                                 ...
# 192  103  年鳳凰颱風農業災情報告 \n103 年 9 月 24 日 17 時 於 農委會統計...
# 193      台灣地區自 7 月 22 日起受麥德姆颱風強風豪雨影響，造成農業災情，經本會畜牧處、...
# 194  　　臺灣地區自 9 月 20 日起受天兔颱風影響，造成農業災情，經本會畜牧處、農糧署、林務局...
# 195  臺灣地區自9月27日起受颱風強風豪雨影響，造成農業災情，經本會畜牧處、農糧署、漁業署及林務局...
# 196  105年9月29日11時\n                                ...
#
# [197 rows x 6 columns]
