# %%
import requests
from bs4 import BeautifulSoup

form_data = {
    'keyword': '鳳梨',
    'division_lv1': '*',
    'year': 102,
    'month': 1,
    'end_year': 110,
    'end_month': 6,
    'search_Submit': '查詢',
    'is_search': 'y'
}

headers = {
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36',
}
url = 'https://www.coa.gov.tw/theme_list.php?theme=news&sub_theme=agri'
ss = requests.session()
res = ss.post(url=url, headers=headers, data=form_data)
soup = BeautifulSoup(res.text, 'html.parser')

ID = []
date = []
title = []
author = []
link = []
content = []


# 取文號
for a in soup.select('td[class="word"]'):
    ID.append(a.text)

# 取發布日期
for b in range(1, len(soup.select('td[align="center"]')), 3):
    newsDate = soup.select('td[align="center"]')[b]
    date.append(newsDate.text)

# 取發布機關
for c in range(2, len(soup.select('td[align="center"]')), 3):
    newsAuthor = soup.select('td[align="center"]')[c]
    author.append(newsAuthor.text)

# 取新聞標題、網址
for i in range(0, len(soup.select('a[class="main-c9-index"]'))):
    newsTitle = soup.select('a[class="main-c9-index"]')[i]['title']
    newsLink = 'https://www.coa.gov.tw/' + soup.select('a[class="main-c9-index"]')[i]['href']
    title.append(newsTitle)
    link.append(newsLink)

# 取新聞內容
for j in range(len(link)):
    page_res = ss.get(url=link[j], headers=headers)
    page_soap = BeautifulSoup(page_res.text, 'html.parser')
    for w in page_soap.select('div[class="word"]'):
        content.append (w.text)


# print(ID)
# print(date)
# print(title)
# print(author)
# print(link)
# print(content)

# %%
import pandas as pd
import csv

dict = {'文號': ID, '發布日期': date, '標題': title, '發布機關': author, '網址': link, '內容': content}
df = pd.DataFrame(dict)
df.to_csv('農委會新聞_鳳梨.csv')
df
# Out:
#           文號       發布日期                                     標題      發布機關  \
# 0       8747  110-06-03                    慎防彩雲颱風 農委會籲請農漁民及早防範  農委會(輔導處)
# 1       8743  110-05-20           農委會邀請全國農業行政首長 齊心推動疫情警戒升級因應措施  農委會(秘書室)
# 2       8722  110-04-09         日商Farmind株式會社承諾購買3,000公噸臺灣優質鳳梨  農委會(國際處)
# 3       8720  110-04-01              買鳳梨挺農民網購活動4/1開賣 歡迎消費者踴躍選購  農委會(國際處)
# 4       8719  110-03-30                     臺灣鳳梨層層把關  提升外銷到貨品質  農委會(國際處)
# ..       ...        ...                                    ...       ...
# 179     6688  102-01-30  因應經貿自由化  農業須有新戰略思維 農委會迄今並未增加開放中國農產品    農委會(企劃處)
# 180     6677  102-01-16             氣象局發布低溫特報  農委會籲請農漁牧養殖業嚴防寒害  農委會(輔導處)
# 181  1070626  107-06-26                       107年0613豪雨農業災情報告  農委會(統計室)
# 182  1030730  103-07-30                       103年麥德姆颱風農業災情報告   農委會(統計室)
# 183  1020910  102-09-10                          潭美及康芮颱風農業災情報告  農委會(統計室)
#
#                                                     網址  \
# 0    https://www.coa.gov.tw/theme_data.php?theme=ne...
# 1    https://www.coa.gov.tw/theme_data.php?theme=ne...
# 2    https://www.coa.gov.tw/theme_data.php?theme=ne...
# 3    https://www.coa.gov.tw/theme_data.php?theme=ne...
# 4    https://www.coa.gov.tw/theme_data.php?theme=ne...
# ..                                                 ...
# 179  https://www.coa.gov.tw/theme_data.php?theme=ne...
# 180  https://www.coa.gov.tw/theme_data.php?theme=ne...
# 181  https://www.coa.gov.tw/theme_data.php?theme=ne...
# 182  https://www.coa.gov.tw/theme_data.php?theme=ne...
# 183  https://www.coa.gov.tw/theme_data.php?theme=ne...
#
#                                                     內容
# 0    　　中央氣象局於本(3)日發布輕度颱風「彩雲」海上颱風警報，颱風中心目前在鵝鑾鼻南南西方海面...
# 1           中央流行疫情指揮中心於19日宣布全國COVID-19疫情警戒升為第三級，農委會...
# 2           農委會陳吉仲主任委員4月9日與日本Farmind株式會社崛內達生社長舉行視訊會...
# 3          中國大陸片面宣布自3月1日起暫停臺灣鳳梨輸入，國內40家電商平臺在農委會的號召下...
# 4           針對近日新加坡消費者反應部分臺灣鳳梨品質不符合期待，農委會今(30)日召開記者...
# ..                                                 ...
# 179        針對媒體報導「中國農產品將攻臺、消滅臺灣農業」乙節，農委會表示，該會自民國 97...
# 180  \r\n　　農委會表示，根據中央氣象局發布之低溫特報，今 (16) 日晚起寒流南下影響，各地...
# 181  　　臺灣地區本（6）月受滯留鋒面引進豪雨影響，造成農業災情，經本會農糧署彙整各直轄市、縣市政...
# 182      台灣地區自 7 月 22 日起受麥德姆颱風強風豪雨影響，造成農業災情，經本會畜牧處、...
# 183  潭美及康芮颱風農業災情報告 \n102 年 9 月 10 日 11 時\n於 農委會統計室\...
#
# [184 rows x 6 columns]
